# %% [markdown]
# <a href="https://colab.research.google.com/github/Pooja-V15/NVIDIA-AI-ML-Internship/blob/main/day-10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install inference-sdk

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="8E9L3seALWnMVr0yjb79")

print(rf.workspace())
# Out:
# loading Roboflow workspace...
# {
#   "name": "Poojas Workspace",
#   "url": "poojas-workspace-decv0",
#   "projects": [
#     "poojas-workspace-decv0/pooh-zhuse",
#     "poojas-workspace-decv0/pooja-wplzd"
#   ]
# }

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="8E9L3seALWnMVr0yjb79")

workspace = rf.workspace("poojas-workspace-decv0")

project = workspace.project("pooh-zhuse")

model = project.version(1).model

result = model.predict("sam.jpg").json()

print(result)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# {'predictions': [{'inference_id': '77ce841c-d1da-4cb1-b7e7-09e358a57d5a', 'time': 0.004824343137443066, 'image': {'width': 194, 'height': 260}, 'predictions': [{'class': 'cat', 'class_id': 1, 'confidence': 0.7736}], 'top': 'cat', 'confidence': 0.7736, 'image_path': 'sam.jpg', 'prediction_type': 'ClassificationModel'}], 'image': (194, 260)}

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="8E9L3seALWnMVr0yjb79")

workspace = rf.workspace("poojas-workspace-decv0")

project = workspace.project("pooh-zhuse")

model = project.version(1).model

result = model.predict("samy.jpg").json()

print(result)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# {'predictions': [{'inference_id': '12d04c5e-c530-416b-a11e-7470ce5cd54b', 'time': 0.0058499108999967575, 'image': {'width': 172, 'height': 293}, 'predictions': [{'class': 'dog', 'class_id': 0, 'confidence': 0.5118}, {'class': 'cat', 'class_id': 1, 'confidence': 0.4882}], 'top': 'dog', 'confidence': 0.5118, 'image_path': 'samy.jpg', 'prediction_type': 'ClassificationModel'}], 'image': (172, 293)}

# %%
pip install inference-sdk

# %%
# !pip install roboflow
# Out:
# ...
#   Using cached roboflow-1.3.10-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
#   Using cached pi_heif-1.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.3 kB)
# ...
#   Using cached pillow_avif_plugin-1.5.5-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# ...
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# ...
# Using cached roboflow-1.3.10-py3-none-any.whl (250 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 81.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 104.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="8E9L3seALWnMVr0yjb79")

print(rf.workspace())
# Out:
# loading Roboflow workspace...
# {
#   "name": "Poojas Workspace",
#   "url": "poojas-workspace-decv0",
#   "projects": [
#     "poojas-workspace-decv0/claasif",
#     "poojas-workspace-decv0/pooh-zhuse",
#     "poojas-workspace-decv0/pooja-wplzd",
#     "poojas-workspace-decv0/pooja2",
#     "poojas-workspace-decv0/pooja3",
#     "poojas-workspace-decv0/pooja4"
#   ]
# }

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="8E9L3seALWnMVr0yjb79")

workspace = rf.workspace("poojas-workspace-decv0")

project = workspace.project("claasif")

model = project.version(1).model

result = model.predict("pos.jpg").json()

print(result)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_2873/149695015.py in <cell line: 0>()
#       7 project = workspace.project("claasif")
#       8
# ----> 9 model = project.version(1).model
#      10
#      11 result = model.predict("pos.jpg").json()
#
# /usr/local/lib/python3.12/dist-packages/roboflow/core/project.py in version(self, version_number, local)
#     355                 return vers
#     356
# --> 357         raise RuntimeError(f"Version number {version_number} is not found.")
#     358
#     359     def check_valid_image(self, image_path: str) -> bool:
#
# RuntimeError: Version number 1 is not found.
